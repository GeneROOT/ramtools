# %%
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
from glob import glob

from parse_utils import load_samtoram_folder, load_index_folder

# %% [markdown]
# # samtobam VS samtoram

# %%
folders = ['opladev47/samexample_samtoram', 'opladev47/6148s100_samtoram', 'data/6148_samtoram']

df_convert = pd.concat([load_samtoram_folder(f) for f in folders], ignore_index=True)
df_convert
# Out:
# opladev47/samexample_samtoram/samtoram_samexample_lzma_nosplit_index.perf
# opladev47/samexample_samtoram/samtoram_samexample_zlib_nosplit_index.perf
# opladev47/samexample_samtoram/samtoram_samexample_zlib_split_index.perf
# opladev47/samexample_samtoram/samtoram_samexample_lzma_split_index.perf
# opladev47/samexample_samtoram/samtobam_samexample.perf
# opladev47/6148s100_samtoram/samtoram_6148s100_lzma_nosplit_index.perf
# opladev47/6148s100_samtoram/samtoram_6148s100_zlib_split_index.perf
# opladev47/6148s100_samtoram/samtoram_6148s100_zlib_nosplit_index.perf
# opladev47/6148s100_samtoram/samtoram_6148s100_lzma_split_index.perf
# opladev47/6148s100_samtoram/samtobam_6148s100.perf
# data/6148_samtoram/samtoram_lzma_split.perf
# data/6148_samtoram/samtoram_lzma_nosplit.perf
# data/6148_samtoram/samtoram_zlib_nosplit.perf
# data/6148_samtoram/samtoram_zlib_split.perf
# data/6148_samtoram/samtobam.perf
#           file                  method  usertime  systemtime  cpu_usage  \
# ...

# %% [markdown]
# # bamindex VS ramindex

# %%
folders = ['opladev47/samexample_index','opladev47/6148s100_index']

df_index = pd.concat([load_index_folder(f) for f in folders], ignore_index=True)
# Out:
# opladev47/samexample_index/ramindex__samexample_lzma_nosplit.root.perf
# opladev47/samexample_index/ramindex__samexample_zlib_split.root.perf
# opladev47/samexample_index/ramindex__samexample_zlib_nosplit.root.perf
# opladev47/samexample_index/ramindex__samexample_lzma_split.root.perf
# opladev47/samexample_index/bamindex__samexample.bam.perf
# opladev47/6148s100_index/ramindex__6148s100_zlib_nosplit.root.perf
# opladev47/6148s100_index/ramindex__6148s100_zlib_split.root.perf
# opladev47/6148s100_index/ramindex__6148s100_lzma_split.root.perf
# opladev47/6148s100_index/ramindex__6148s100_lzma_nosplit.root.perf
# opladev47/6148s100_index/bamindex__6148s100.bam.perf

# %%
df_index
# Out:
#          file                  method  usertime  systemtime  cpu_usage  \
# 0  samexample  ramtools__lzma_nosplit      1.07        0.31       27.0
# 1  samexample    ramtools__zlib_split      0.75        0.28       22.0
# 2  samexample  ramtools__zlib_nosplit      0.70        0.69       28.0
# 3  samexample    ramtools__lzma_split      3.92        0.83       39.0
# 4  samexample                samtools      0.01        0.00       18.0
# 5    6148s100  ramtools__zlib_nosplit      7.20        0.89       54.0
# 6    6148s100    ramtools__zlib_split     45.36        1.50       88.0
# 7    6148s100    ramtools__lzma_split     14.93        0.76       73.0
# 8    6148s100  ramtools__lzma_nosplit    201.91        1.32       94.0
# 9    6148s100                samtools     16.22        0.61       94.0
#
#     memory    filesize   size_GB
# 0   105208     1944486  0.001811
# 1   104648     2343220  0.002182
# 2   104724     2306015  0.002148
# 3   137584     1850348  0.001723
# ...

# %%
python tools_perf.py index ram -iS --out data/samexample_index data/samexample_*root
